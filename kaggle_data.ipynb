# %%
import pandas as pd
df= pd.read_csv("kaggleDATA.csv")
df
# df.describe()
# Out:
#         Id        Date   Time  CO2_(dinning-room)  CO2_room  \
# 0        0  13/03/2012  11:45             216.560   221.920
# 1        1  13/03/2012  12:00             219.947   220.363
# 2        2  13/03/2012  12:15             219.403   218.933
# 3        3  13/03/2012  12:30             218.613   217.045
# 4        4  13/03/2012  12:45             217.714   216.080
# ...    ...         ...    ...                 ...       ...
# 2759  2759  11/04/2012  05:30             190.539   192.181
# 2760  2760  11/04/2012  05:45             190.421   193.067
# 2761  2761  11/04/2012  06:00             190.432   193.653
# 2762  2762  11/04/2012  06:15             191.531   193.387
# 2763  2763  11/04/2012  06:30             191.563   193.664
#
#       Relative_humidity_(dinning-room)  Relative_humidity_room  \
# 0                              39.9125                 42.4150
# 1                              39.9267                 42.2453
# ...

# %%
df1 = df.drop(columns=["CO2_(dinning-room)", "Relative_humidity_(dinning-room)", "Lighting_(dinning-room)", "Lighting_room", "Meteo_Rain", "Meteo_Sun_dusk", "Meteo_Sun_light_in_west_facade", "Meteo_Sun_light_in_east_facade", "Meteo_Sun_light_in_south_facade", "Meteo_Sun_irradiance"])
df1
# Out:
#         Id        Date   Time  CO2_room  Relative_humidity_room  Meteo_Wind  \
# 0        0  13/03/2012  11:45   221.920                 42.4150    1.426250
# 1        1  13/03/2012  12:00   220.363                 42.2453    1.592000
# 2        2  13/03/2012  12:15   218.933                 42.2267    1.891330
# 3        3  13/03/2012  12:30   217.045                 42.0987    1.828000
# 4        4  13/03/2012  12:45   216.080                 42.0686    2.360710
# ...    ...         ...    ...       ...                     ...         ...
# 2759  2759  11/04/2012  05:30   192.181                 41.6880    0.074667
# 2760  2760  11/04/2012  05:45   193.067                 41.7200    0.000000
# 2761  2761  11/04/2012  06:00   193.653                 41.7573    0.310667
# 2762  2762  11/04/2012  06:15   193.387                 41.8107    0.299333
# 2763  2763  11/04/2012  06:30   193.664                 41.8373    0.908000
#
# ...

# %%
import pandas as pd
import numpy as np

# Define column names
columns = ["Timestamp", "Temperature (°C)", "Humidity (%)", "Moisture Level (%)", "Gas Level (PPM)"]

# Generate timestamps for 4 hours
timestamps = pd.date_range(start="2025-03-06 08:00:00", periods=4, freq="H")

# Manually adjust values so that the first three hours are predicted as "Safe" and the fourth hour as "Risky"
data = {
    "Timestamp": timestamps,
    "Temperature (°C)": [25, 26, 24, 35],  # Increase in the 4th hour
    "Humidity (%)": [55, 58, 53, 80],  # Sharp rise in humidity in 4th hour
    "Moisture Level (%)": [12, 13, 11, 25],  # High moisture level in 4th hour
    "Gas Level (PPM)": [120, 125, 110, 300]  # Sudden spike in gas levels
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Save the new dataset to CSV
df.to_csv("generated_grain_storage.csv", index=False)

print("✅ New dataset generated and saved as 'generated_grain_storage.csv' successfully!")
# Out:
# ✅ New dataset generated and saved as 'generated_grain_storage.csv' successfully!
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_24976\2319615615.py:8: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   timestamps = pd.date_range(start="2025-03-06 08:00:00", periods=4, freq="H")
